# %%
# # 사진의 유사도를 확인하는 코딩

# from transformers import CLIPProcessor, CLIPModel
# from PIL import Image
# import torch

# model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
# processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# # 이미지 로드
# image1 = Image.open("RICO1 (9741).jpg")
# image2 = Image.open("AC0A9618.jpg")

# # 임베딩 생성
# inputs1 = processor(images=image1, return_tensors="pt")
# inputs2 = processor(images=image2, return_tensors="pt")

# with torch.no_grad():
#     embeddings1 = model.get_image_features(**inputs1)
#     embeddings2 = model.get_image_features(**inputs2)

# # 코사인 유사도 계산
# similarity = torch.nn.functional.cosine_similarity(embeddings1, embeddings2)
# print(f"유사도: {similarity.item()}")
# Out:
# 유사도: 0.8600329756736755

# %%
# CLIP 사용 (가장 추천)
from transformers import CLIPProcessor, CLIPModel
import torch

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 모든 이미지의 임베딩을 미리 계산하여 저장
embeddings = np.array([...])  # (N, 512) 형태
query_embedding = np.array([...])  # (1, 512)

# 유사도 계산
similarities = cosine_similarity(query_embedding, embeddings)
top_indices = np.argsort(similarities[0])[::-1][:10]  # 상위 10개
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6 query_embedding = np.array([...])  # (1, 512)
#       8 # 유사도 계산
# ----> 9 similarities = cosine_similarity(query_embedding, embeddings)
#      10 top_indices = np.argsort(similarities[0])[::-1][:10]  # 상위 10개
#
# File c:\Users\Admin\miniconda3\envs\gpt_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
#이미지 처리

from PIL import Image
import os

def load_and_preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return image

# %%
# 파일관리

import glob

# 폴더 내 모든 이미지 찾기
image_extensions = ['*.jpg', '*.jpeg', '*.png', '*.bmp']
image_paths = []
for ext in image_extensions:
    image_paths.extend(glob.glob(f'your_folder/**/{ext}', recursive=True))
```

# ## 전체 시스템 구조
# ```
# 1. 전처리 단계 (한 번만 실행)
#    ↓
#    폴더 내 모든 사진 → 임베딩 생성 → 저장 (pickle/numpy)
   
# 2. 검색 단계
#    ↓
#    나의 사진 → 임베딩 생성 → 유사도 계산 → 상위 N개 반환
